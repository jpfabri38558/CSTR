# %% [markdown]
# <a href="https://colab.research.google.com/github/jpfabri38558/CSTR/blob/main/Modelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def modelCSTR(CAin, parameters):
  """
  Calcula o valor da concentração de saída do CSTR.
  CAin - concentração de entrada do reator
  parameters - parâmetros do reator
  """
  k = parameters.k
  F = parameters.F
  V = parameters.V
  return (F*CAin)/(F + k*V)
